# %% [markdown]
# **Project Name**- AirBnb Booking Analysis

# %% [markdown]
# **Project Type** - EDA
#
# **Contribution**- Muhammad Waqar

# %% [markdown]
# **Github Link**- https://github.com/Waqar1234567

# %% [markdown]
# **Problem Statement**

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more.
#
# This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values.
#
# Explore and analyze the data to discover key understandings.

# %% [markdown]
# **Let's Begin**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
air_df= pd.read_csv('/content/drive/MyDrive/Airbnb NYC 2019.csv')

# %%
air_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
air_df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
air_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
air_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
airdf1=air_df.copy()

# %% [markdown]
# Clear Data and Fixing Null Vlaues

# %%
airdf1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='longitude',y='latitude',data=airdf1,hue='neighbourhood_group')
plt.show()

# %%
airdf1.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
airdf1['name'].fillna('unregister', inplace=True)

# %%
airdf1.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
airdf1['host_name'].fillna('unknown', inplace=True)

# %%
airdf1['reviews_per_month'].fillna(0, inplace=True)

# %%
airdf1.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
airdf1.drop(['last_review'] , axis=1, inplace=True)

# %%
airdf1.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# Check Duplicate Host Id

# %%
airdf1.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
airdf1.shape
# Out:
# (48895, 15)

# %%
airdf1['host_id'].value_counts()
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
#             ...
# 23727216       1
# 89211125       1
# 19928013       1
# 1017772        1
# 68119814       1
# Name: host_id, Length: 37457, dtype: int64

# %%
airdf1['id'].value_counts()
# Out:
# 2539        1
# 25583366    1
# 25551687    1
# 25552076    1
# 25554120    1
#            ..
# 13121809    1
# 13122135    1
# 13122318    1
# 13122932    1
# 36487245    1
# Name: id, Length: 48895, dtype: int64

# %%
airdf1['host_name'].value_counts()
# Out:
# Michael              417
# David                403
# Sonder (NYC)         327
# John                 294
# Alex                 279
#                     ...
# Rhonycs                1
# Brandy-Courtney        1
# Shanthony              1
# Aurore And Jamila      1
# Ilgar & Aysel          1
# Name: host_name, Length: 11453, dtype: int64

# %%
airdf1['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
sns.countplot(x='neighbourhood_group', data=airdf1)
plt.show()

# %% [markdown]
# Questions

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='neighbourhood_group', data=airdf1 , hue='room_type')
plt.show()

# %% [markdown]
# Top 10 Host

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=airdf1['host_name'].value_counts().keys()[0:10], y=airdf1['host_name'].value_counts()[:10], data=airdf1)
plt.show()

# %% [markdown]
# Total No. of Each Room Type

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='room_type', data=airdf1 )
plt.show()

# %% [markdown]
# Rooms Type in Neighbourhood Group

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='room_type', data=airdf1, hue='neighbourhood_group')
plt.show()

# %%
airdf1['price'].value_counts().sort_values(ascending=False)
# Out:
# 100     2051
# 150     2047
# 50      1534
# 60      1458
# 200     1401
#         ...
# 1497       1
# 2850       1
# 990        1
# 8000       1
# 338        1
# Name: price, Length: 674, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='neighbourhood_group',y='price' ,data=airdf1, hue='room_type')
plt.show()

# %%
airdf1.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x='availability_365',y='neighbourhood_group' ,data=airdf1)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(y='availability_365',x='price' ,data=airdf1)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='availability_365',x='neighbourhood_group' ,data=airdf1)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(y='availability_365',x='neighbourhood_group' ,data=airdf1)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(y='price',x='neighbourhood_group' ,data=airdf1)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='price',x='neighbourhood_group' ,data=airdf1)
plt.show()

# %% [markdown]
# Which neighbourhood_group has maximum no. of private rooms ?

# %%
max_private = airdf1[airdf1['room_type']=='Private room']

# %%
max_private.head(2)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0            Brooklyn    Kensington  40.64749  -73.97237  Private room    149
# 2           Manhattan        Harlem  40.80902  -73.94190  Private room    150
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9               0.21
# 2               3                  0               0.00
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 2                               1               365

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='neighbourhood_group' ,data=max_private)
plt.title('Maximum Private Rooms in Neighbourhood Group')
plt.show()

# %% [markdown]
# We can see in Maximum Private Rooms in Neighbourhood Group graph Brooklyn has maximum no. of ( 10132 ) Private Rooms in Neighbourhood Group.
#
# Below we can see a list of Maximum Private Rooms in Neighbourhood Group.

# %%
max_private['neighbourhood_group'].value_counts()
# Out:
# Brooklyn         10132
# Manhattan         7982
# Queens            3372
# Bronx              652
# Staten Island      188
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# Average Price for rooms in neighbourhood groups

# %%
airdf1.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
avg_price = airdf1.groupby('neighbourhood_group')

# %%
avg_price['price'].mean()
# Out:
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
sns.barplot(x=avg_price['price'].mean().keys(), y=avg_price['price'].mean())
plt.title('Average Price for rooms in neighbourhood groups')
plt.show()

# %% [markdown]
# In Average Price for rooms in neighbourhood groups graph we see average price of groups in all neighbourhood groups. Manhattan has maximum average room price in comparsion all others neighbourhood cities. Bronx has Minimum average Rooms Price.

# %% [markdown]
# List of Average Price per Night Based on the Neighbourhood Group

# %%
avg_price.head()
# Out:
#         id                                               name  host_id  \
# 0     2539                 Clean & quiet apt home by the park     2787
# 1     2595                              Skylit Midtown Castle     2845
# 2     3647                THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3     3831                    Cozy Entire Floor of Brownstone     4869
# 4     5022   Entire Apt: Spacious Studio/Loft by central park     7192
# 5     5099          Large Cozy 1 BR Apartment In Midtown East     7322
# 6     5121                                    BlissArtsSpace!     7356
# 7     5178                   Large Furnished Room Near B'way      8967
# 12    5803     Lovely Room 1, Garden, Best Area, Legal rental     9744
# 15    6848                   Only 2 stops to Manhattan studio    15991
# 46   12937  1 Stop fr. Manhattan! Private Suite,Landmark B...    50124
# 77   18198                              Little King of Queens    70091
# ...

# %%
avg_price[['neighbourhood_group','minimum_nights', 'price']].head(2)
# Out:
#     neighbourhood_group  minimum_nights  price
# 0              Brooklyn               1    149
# 1             Manhattan               1    225
# 2             Manhattan               3    150
# 3              Brooklyn               1     89
# 46               Queens               3    130
# 77               Queens              30     70
# 169       Staten Island               2     70
# 171               Bronx               1     40
# 207               Bronx               1     45
# 249       Staten Island               2     36

# %%
avg_price['neighbourhood_group', 'neighbourhood'].head()
# Out:
# <ipython-input-91-3d585ce10453>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg_price['neighbourhood_group', 'neighbourhood'].head()
#     neighbourhood_group       neighbourhood
# 0              Brooklyn          Kensington
# 1             Manhattan             Midtown
# 2             Manhattan              Harlem
# 3              Brooklyn        Clinton Hill
# 4             Manhattan         East Harlem
# 5             Manhattan         Murray Hill
# 6              Brooklyn  Bedford-Stuyvesant
# 7             Manhattan      Hell's Kitchen
# 12             Brooklyn         South Slope
# 15             Brooklyn        Williamsburg
# 46               Queens    Long Island City
# 77               Queens            Woodside
# 143              Queens            Flushing
# 161              Queens           Sunnyside
# 169       Staten Island          St. George
# ...

# %% [markdown]
# Top 10 Neighbourhood

# %%
top_10loc =airdf1['neighbourhood'].value_counts().sort_values(ascending=False)[:10]

# %%
plt.figure(figsize=(20,6))
sns.barplot(x=airdf1['neighbourhood'].value_counts().sort_values(ascending=False)[:10].keys(), y=airdf1['neighbourhood'].value_counts().sort_values(ascending=False)[:10] , data=airdf1)
plt.show()

# %% [markdown]
# Top 15 Most Expensive Locality in Airbnb NYC

# %%
airdf1.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
top_loc = airdf1.groupby('neighbourhood')

# %%
apn =top_loc['neighbourhood', 'price'].head().sort_values(by='price', ascending=False)
# Out:
# <ipython-input-96-d021adcb8d83>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   apn =top_loc['neighbourhood', 'price'].head().sort_values(by='price', ascending=False)

# %%
top_15_expensive  = apn.head(15)

# %%
apn.head(15)
# Out:
#            neighbourhood  price
# 22353      Randall Manor   5000
# 3731     Stuyvesant Town   1500
# 3761            Sea Gate   1485
# 5499    Roosevelt Island   1400
# 42172           Sea Gate   1315
# 45572       Prince's Bay   1250
# 662    Greenwich Village    850
# 85      Brooklyn Heights    800
# 1201    Brooklyn Heights    800
# 25386     Fort Wadsworth    800
# 14747    Jamaica Estates    750
# 3049             Woodrow    700
# 1621            Arrochar    625
# 6784     Stuyvesant Town    600
# 299         Little Italy    575

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='neighbourhood', y= 'price', data=top_15_expensive,)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Top 15 least Expensive

# %%
top_15_least  = apn.tail(15)

# %%
top_15_least
# Out:
#             neighbourhood  price
# 24983         Morris Park     29
# 19341    South Ozone Park     29
# 10891           Soundview     28
# 35653  Westchester Square     28
# 15004      Morris Heights     26
# 30607           Olinville     26
# 29738         Bull's Head     25
# 6108             Van Nest     25
# 48312           Olinville     25
# 31203          Mount Eden     25
# 17735          Highbridge     22
# 957          Graniteville     20
# 29852         South Beach     20
# 21733       Schuylerville     20
# 25433     East Morrisania      0

# %%
plt.figure(figsize=(25,6))
sns.barplot(x='neighbourhood', y= 'price', data=top_15_least,)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Top 10 Locality Based on reviews

# %%
top_reveiws =top_loc['neighbourhood','host_name', 'number_of_reviews'].head().sort_values(by='number_of_reviews', ascending=False)
# Out:
# <ipython-input-103-86d2e2529f44>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   top_reveiws =top_loc['neighbourhood','host_name', 'number_of_reviews'].head().sort_values(by='number_of_reviews', ascending=False)

# %%
top_r=top_reveiws.head(10)

# %%
top_r
# Out:
#                   neighbourhood       host_name  number_of_reviews
# 1271                   Flushing           Linda                474
# 113                 South Slope            Dani                467
# 1103                    Jamaica           Lloyd                454
# 257                     Astoria  Dennis & Naoko                441
# 7                Hell's Kitchen        Shunichi                430
# 435                     Astoria    Gladys & Bob                414
# 534   Prospect-Lefferts Gardens          Dennis                401
# 3020                  Woodhaven         Antonio                386
# 6226              East Elmhurst          Angela                356
# 119                 South Slope          Evelyn                354

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='neighbourhood' ,y='number_of_reviews' , data=top_r)
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='host_name' ,y='number_of_reviews' , data=top_r)
plt.show()

# %%
airdf1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# ...

# %% [markdown]
# 'Distribution of Prices in neighbourhoods'

# %%
fig = plt.figure(figsize=(24, 6))
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)
sns.lineplot(data=airdf1, x='neighbourhood', y='price', hue='room_type')
plt.title('Distribution of Prices in neighbourhoods')
sns.despine(fig)

# %% [markdown]
# Scatterplot of Room Type

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='longitude',y='latitude' ,data=airdf1, hue='room_type')
plt.ioff()
plt.show()

# %%
airdf1.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price',y='reviews_per_month' ,data=airdf1)
plt.show()

# %% [markdown]
# Which Room Type is prefered in each neighbourhood

# %%
sns.barplot(x='room_type',y='reviews_per_month',data=airdf1 ,hue='neighbourhood_group')
plt.plot(loc=2)
sns.set(rc={'figure.figsize':(20,11)})

# %% [markdown]
# Availability Of Rooms At Different Neighbourhood Groups

# %%
sns.boxplot(x='neighbourhood_group',y='availability_365',data=airdf1)
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='availability_365'>

# %% [markdown]
# Which Type of Rooms preferred by customers for night stay

# %%
sns.barplot(x='room_type',y='minimum_nights',data=airdf1)
plt.show()

# %% [markdown]
# **Conclusion**

# %% [markdown]
# Manhattan is the most focussed place for the hosts to do their  business
